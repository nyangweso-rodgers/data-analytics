# %% [markdown]
# # How To Filter Pandas DataFrame

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/nyangweso-rodgers/Data_Analytics/main/Datasets/Online_Retail.csv"
raw_data = pd.read_csv(url, encoding= 'unicode_escape', parse_dates=['InvoiceDate'])
raw_data.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %% [markdown]
# ## Examples Of Filtering

# %% [markdown]
# ### 1: Get Transactions from Country Brazil
# * You can use __isin()__ method.

# %%
raw_data[raw_data['Country'].isin(['Brazil'])]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 157299    550201     22423            REGENCY CAKESTAND 3 TIER        16
# 157300    550201     22699    ROSES REGENCY TEACUP AND SAUCER         24
# 157301    550201     22697     GREEN REGENCY TEACUP AND SAUCER        24
# 157302    550201     22698      PINK REGENCY TEACUP AND SAUCER        24
# 157303    550201     22366                    DOORMAT AIRMAIL         10
# 157304    550201     21430  SET/3 RED GINGHAM ROSE STORAGE BOX        24
# 157305    550201     22630                DOLLY GIRL LUNCH BOX        24
# 157306    550201     22662         LUNCH BAG DOLLY GIRL DESIGN        10
# 157307    550201     22629                 SPACEBOY LUNCH BOX         12
# 157308    550201     22382          LUNCH BAG SPACEBOY DESIGN         10
# 157309    550201   15056BL             EDWARDIAN PARASOL BLACK         3
# 157310    550201    15056P              EDWARDIAN PARASOL PINK         3
# 157311    550201    15056N           EDWARDIAN PARASOL NATURAL         3
# 157312    550201     20679               EDWARDIAN PARASOL RED         3
# 157313    550201     21166          COOK WITH WINE METAL SIGN         12
# 157314    550201     21181        PLEASE ONE PERSON METAL SIGN        12
# 157315    550201     21770              OPEN CLOSED METAL SIGN        10
# 157316    550201     22993        SET OF 4 PANTRY JELLY MOULDS        24
# 157317    550201     22722   SET OF 6 SPICE TINS PANTRY DESIGN        24
# 157318    550201     23179          CLOCK MAGNET MUM'S KITCHEN         6
# 157319    550201     23178                    JAM CLOCK MAGNET         6
# 157320    550201     22494            EMERGENCY FIRST AID TIN         12
# 157321    550201     21260                       FIRST AID TIN         6
# 157322    550201     21906             PHARMACIE FIRST AID TIN         6
# 157323    550201    84971S           SMALL HEART FLOWERS HOOK         24
# 157324    550201     23054      RECYCLED ACAPULCO MAT LAVENDER         2
# 157325    550201     23053          RECYCLED ACAPULCO MAT PINK         2
# 157326    550201     23050         RECYCLED ACAPULCO MAT GREEN         2
# 157327    550201     23051          RECYCLED ACAPULCO MAT BLUE         2
# 157328    550201     23049           RECYCLED ACAPULCO MAT RED         2
# 157329    550201     23052     RECYCLED ACAPULCO MAT TURQUOISE         2
# 157330    550201     22488  NATURAL SLATE RECTANGLE CHALKBOARD        12
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 157299 2011-04-15 10:25:00      10.95     12769.0  Brazil
# 157300 2011-04-15 10:25:00       2.55     12769.0  Brazil
# 157301 2011-04-15 10:25:00       2.55     12769.0  Brazil
# 157302 2011-04-15 10:25:00       2.55     12769.0  Brazil
# 157303 2011-04-15 10:25:00       6.75     12769.0  Brazil
# 157304 2011-04-15 10:25:00       3.39     12769.0  Brazil
# 157305 2011-04-15 10:25:00       1.95     12769.0  Brazil
# 157306 2011-04-15 10:25:00       1.65     12769.0  Brazil
# 157307 2011-04-15 10:25:00       1.95     12769.0  Brazil
# 157308 2011-04-15 10:25:00       1.65     12769.0  Brazil
# 157309 2011-04-15 10:25:00       5.95     12769.0  Brazil
# 157310 2011-04-15 10:25:00       5.95     12769.0  Brazil
# 157311 2011-04-15 10:25:00       5.95     12769.0  Brazil
# 157312 2011-04-15 10:25:00       5.95     12769.0  Brazil
# 157313 2011-04-15 10:25:00       2.08     12769.0  Brazil
# 157314 2011-04-15 10:25:00       2.10     12769.0  Brazil
# 157315 2011-04-15 10:25:00       4.95     12769.0  Brazil
# 157316 2011-04-15 10:25:00       1.25     12769.0  Brazil
# 157317 2011-04-15 10:25:00       3.45     12769.0  Brazil
# 157318 2011-04-15 10:25:00       2.89     12769.0  Brazil
# 157319 2011-04-15 10:25:00       2.89     12769.0  Brazil
# 157320 2011-04-15 10:25:00       1.25     12769.0  Brazil
# 157321 2011-04-15 10:25:00       3.25     12769.0  Brazil
# 157322 2011-04-15 10:25:00       6.75     12769.0  Brazil
# 157323 2011-04-15 10:25:00       0.85     12769.0  Brazil
# 157324 2011-04-15 10:25:00       8.25     12769.0  Brazil
# 157325 2011-04-15 10:25:00       8.25     12769.0  Brazil
# 157326 2011-04-15 10:25:00       8.25     12769.0  Brazil
# 157327 2011-04-15 10:25:00       8.25     12769.0  Brazil
# 157328 2011-04-15 10:25:00       8.25     12769.0  Brazil
# 157329 2011-04-15 10:25:00       8.25     12769.0  Brazil
# 157330 2011-04-15 10:25:00       1.65     12769.0  Brazil

# %% [markdown]
# ### Example 2: Get Transactions from Malta and Canada

# %%
raw_data[raw_data['Country'].isin(['Malta', 'Canada'])]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 119191    546533     20886              BOX OF 9 PEBBLE CANDLES        12
# 119192    546533    79030D                     TUMBLER, BAROQUE         6
# 119193    546533     21132             SILVER STANDING GNOME            4
# 119194    546533     84879        ASSORTED COLOUR BIRD ORNAMENT         8
# 119195    546533     84755  COLOUR GLASS T-LIGHT HOLDER HANGING        16
# ...          ...       ...                                  ...       ...
# 516550   C579929     22768           FAMILY PHOTO FRAME CORNICE        -2
# 516551   C579929    85034C          3 ROSE MORRIS BOXED CANDLES        -1
# 516552   C579929    72807C  SET/3 VANILLA SCENTED CANDLE IN BOX        -1
# 516553   C579929     22307     GOLD MUG BONE CHINA TREE OF LIFE        -1
# 516554   C579929     72741                GRAND CHOCOLATECANDLE        -3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 119191 2011-03-14 13:53:00       1.95     15388.0  Canada
# 119192 2011-03-14 13:53:00       1.65     15388.0  Canada
# 119193 2011-03-14 13:53:00       4.25     15388.0  Canada
# 119194 2011-03-14 13:53:00       1.69     15388.0  Canada
# 119195 2011-03-14 13:53:00       0.65     15388.0  Canada
# ...                    ...        ...         ...     ...
# 516550 2011-12-01 09:34:00       9.95     17828.0   Malta
# 516551 2011-12-01 09:34:00       1.25     17828.0   Malta
# 516552 2011-12-01 09:34:00       4.25     17828.0   Malta
# 516553 2011-12-01 09:34:00       1.06     17828.0   Malta
# 516554 2011-12-01 09:34:00       1.45     17828.0   Malta
#
# [278 rows x 8 columns]

# %% [markdown]
# ### 3: Get Items whose UnitPrice is greater than $20,000
# * Here we are using __Logical Operators__

# %%
raw_data[raw_data['UnitPrice'] > 20000]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 222681   C556445         M      Manual        -1 2011-06-10 15:31:00
#
#         UnitPrice  CustomerID         Country
# 222681    38970.0     15098.0  United Kingdom

# %% [markdown]
# ### Example 4: Get Items whose UnitPrice is greater than $20,000 and from United Kingdom
# * Occasions may arise where we have to filter our data for multiple conditions.
# * Again, we are use __Logical Operators__

# %%
raw_data[(raw_data['UnitPrice'] > 20000) & (raw_data['Country'] == 'United Kingdom')]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 222681   C556445         M      Manual        -1 2011-06-10 15:31:00
#
#         UnitPrice  CustomerID         Country
# 222681    38970.0     15098.0  United Kingdom

# %% [markdown]
# __REMARK__: _You can also use other logical operators such as less than(<), greater than(>), equal to(=), not equal to(!=), etc._

# %% [markdown]
# ### Example 5: Get Transactions from Belgium
# * Using a __Query Function__
# * The query function takes in an expression as an argument which evaluates to a Boolean that is used to filter the dataframe.

# %%
raw_data.query("Country == 'Belgium'")
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 7279      537026     84375        SET OF 20 KIDS COOKIE CUTTERS        12
# 7280      537026     21217        RED RETROSPOT ROUND CAKE TINS         2
# 7281      537026     21212      PACK OF 72 RETROSPOT CAKE CASES       120
# 7282      537026     21977   PACK OF 60 PINK PAISLEY CAKE CASES       120
# 7283      537026     22417       PACK OF 60 SPACEBOY CAKE CASES       120
# ...          ...       ...                                  ...       ...
# 541194    581493     23204          CHARLOTTE BAG APPLES DESIGN        10
# 541195    581493     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR        18
# 541196    581493     22252  BIRDCAGE DECORATION TEALIGHT HOLDER        12
# 541197    581493     22807         SET OF 6 T-LIGHTS TOADSTOOLS         6
# 541198    581493      POST                              POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID  Country
# 7279   2010-12-03 16:35:00       2.10     12395.0  Belgium
# 7280   2010-12-03 16:35:00       9.95     12395.0  Belgium
# 7281   2010-12-03 16:35:00       0.42     12395.0  Belgium
# 7282   2010-12-03 16:35:00       0.42     12395.0  Belgium
# 7283   2010-12-03 16:35:00       0.42     12395.0  Belgium
# ...                    ...        ...         ...      ...
# 541194 2011-12-09 10:10:00       0.85     12423.0  Belgium
# 541195 2011-12-09 10:10:00       0.79     12423.0  Belgium
# 541196 2011-12-09 10:10:00       1.25     12423.0  Belgium
# 541197 2011-12-09 10:10:00       2.95     12423.0  Belgium
# 541198 2011-12-09 10:10:00      15.00     12423.0  Belgium
#
# [2069 rows x 8 columns]

# %% [markdown]
# * We can also query based on multiple conditions
# * Get Transactions from Belgium whose __UnitPrice__ > 10

# %%
raw_data.query("Country == 'Belgium' and UnitPrice > 10")
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 7290      537026      POST                      POSTAGE         2
# 34464     539391     22423     REGENCY CAKESTAND 3 TIER         4
# 34469     539391     22770               MIRROR CORNICE         2
# 34471     539391      POST                      POSTAGE         2
# 36285     539447     22504  CABIN BAG VINTAGE RETROSPOT         3
# ...          ...       ...                          ...       ...
# 531760    580965     22423     REGENCY CAKESTAND 3 TIER         4
# 531761    580965     23007       SPACEBOY BABY GIFT SET         1
# 531777    580965      POST                      POSTAGE         3
# 531924    580979      POST                      POSTAGE         3
# 541198    581493      POST                      POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID  Country
# 7290   2010-12-03 16:35:00      18.00     12395.0  Belgium
# 34464  2010-12-17 11:51:00      12.75     12417.0  Belgium
# 34469  2010-12-17 11:51:00      14.95     12417.0  Belgium
# 34471  2010-12-17 11:51:00      15.00     12417.0  Belgium
# 36285  2010-12-17 16:00:00      12.75     12395.0  Belgium
# ...                    ...        ...         ...      ...
# 531760 2011-12-06 14:52:00      12.75     12417.0  Belgium
# 531761 2011-12-06 14:52:00      16.95     12417.0  Belgium
# 531777 2011-12-06 14:52:00      15.00     12417.0  Belgium
# 531924 2011-12-06 15:40:00      18.00     12362.0  Belgium
# 541198 2011-12-09 10:10:00      15.00     12423.0  Belgium
#
# [173 rows x 8 columns]

# %% [markdown]
# ## Str Accessor
# * Pandas make it easy to work with string values. Using the str accessor, we can filter for records whose values are strings.

# %%
raw_data[raw_data['Country'].str.contains('b')]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 72985     542276     82551               LAUNDRY 15C METAL SIGN        12
# 72986     542276     21165        BEWARE OF THE CAT METAL SIGN         12
# 72987     542276     82600                NO SINGING METAL SIGN        12
# 72988     542276     21754             HOME BUILDING BLOCK WORD         6
# 72989     542276     21756             BATH BUILDING BLOCK WORD         6
# ...          ...       ...                                  ...       ...
# 383504    570026     84347  ROTATING SILVER ANGELS T-LIGHT HLDR        24
# 383505    570026      POST                              POSTAGE         1
# 479276   C577151    84459A            PINK METAL CHICKEN HEART        -24
# 479277   C577151     22231           JIGSAW TREE WITH BIRDHOUSE       -15
# 481188   C577353      POST                              POSTAGE        -1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 72985  2011-01-27 10:19:00       1.45     12764.0         Lebanon
# 72986  2011-01-27 10:19:00       1.69     12764.0         Lebanon
# 72987  2011-01-27 10:19:00       2.10     12764.0         Lebanon
# 72988  2011-01-27 10:19:00       5.95     12764.0         Lebanon
# 72989  2011-01-27 10:19:00       5.95     12764.0         Lebanon
# ...                    ...        ...         ...             ...
# 383504 2011-10-07 10:37:00       2.55     12781.0  Czech Republic
# 383505 2011-10-07 10:37:00      40.00     12781.0  Czech Republic
# 479276 2011-11-18 09:50:00       1.49     12781.0  Czech Republic
# 479277 2011-11-18 09:50:00       1.45     12781.0  Czech Republic
# 481188 2011-11-18 15:45:00       4.00     12781.0  Czech Republic
#
# [153 rows x 8 columns]

# %%
raw_data[raw_data['Country'].str.startswith('F')]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 26     2010-12-01 08:45:00       3.75     12583.0  France
# 27     2010-12-01 08:45:00       3.75     12583.0  France
# 28     2010-12-01 08:45:00       3.75     12583.0  France
# 29     2010-12-01 08:45:00       0.85     12583.0  France
# 30     2010-12-01 08:45:00       0.65     12583.0  France
# ...                    ...        ...         ...     ...
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France
#
# [9252 rows x 8 columns]

# %% [markdown]
# ## nlargest and nsmallest
# * Most times, we just need records of the highest or lowest values in a column. These methods make it possible.

# %%
# get highest 3 transactions with highest UnitPrice
raw_data.nlargest(3, 'UnitPrice')
# Out:
#        InvoiceNo  StockCode Description  Quantity         InvoiceDate  \
# 222681   C556445          M      Manual        -1 2011-06-10 15:31:00
# 524602   C580605  AMAZONFEE  AMAZON FEE        -1 2011-12-05 11:36:00
# 43702    C540117  AMAZONFEE  AMAZON FEE        -1 2011-01-05 09:55:00
#
#         UnitPrice  CustomerID         Country
# 222681   38970.00     15098.0  United Kingdom
# 524602   17836.46         NaN  United Kingdom
# 43702    16888.02         NaN  United Kingdom

# %% [markdown]
# * Get bottom 3 transactions with lowest __UnitPrice__

# %%
raw_data.nsmallest(3, 'UnitPrice')
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
# 622       536414     22139              NaN        56 2010-12-01 11:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom
# 622          0.00         NaN  United Kingdom

# %% [markdown]
# ## Tilde sign (~)
# *  Used to reverse the logic used in filter condition

# %%
raw_data[~raw_data['Country'].str.contains('b')]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541756 rows x 8 columns]

# %%
raw_data[~raw_data['Country'].isin(['United Kingdom', 'Brazil'])]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 26     2010-12-01 08:45:00       3.75     12583.0  France
# 27     2010-12-01 08:45:00       3.75     12583.0  France
# 28     2010-12-01 08:45:00       3.75     12583.0  France
# 29     2010-12-01 08:45:00       0.85     12583.0  France
# 30     2010-12-01 08:45:00       0.65     12583.0  France
# ...                    ...        ...         ...     ...
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France
#
# [46399 rows x 8 columns]

# %% [markdown]
# ## isnull | notnull
# * Using the __isnull__ method, we can return records that have __NaN__ values and mark them for deletion.
# * Using the __notnull__ method, we can filter for records that do not contain __NaN__ values.

# %%
# transactions with null customerid
raw_data[raw_data['CustomerID'].isnull()]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 622    2010-12-01 11:52:00       0.00         NaN  United Kingdom
# 1443   2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1444   2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1445   2010-12-01 14:32:00       0.85         NaN  United Kingdom
# 1446   2010-12-01 14:32:00       1.66         NaN  United Kingdom
# ...                    ...        ...         ...             ...
# 541536 2011-12-09 10:26:00       4.13         NaN  United Kingdom
# 541537 2011-12-09 10:26:00       4.13         NaN  United Kingdom
# 541538 2011-12-09 10:26:00       4.96         NaN  United Kingdom
# 541539 2011-12-09 10:26:00      10.79         NaN  United Kingdom
# 541540 2011-12-09 10:26:00    1714.17         NaN  United Kingdom
#
# [135080 rows x 8 columns]

# %%
# transactions with CustomerID
raw_data[raw_data['CustomerID'].notnull()]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [406829 rows x 8 columns]

# %% [markdown]
# ## Filter
# * Using this method, we can also filter for a subset of data.

# %%
raw_data.filter(items=['CustomerID', 'Country'], axis=1)
# Out:
#         CustomerID         Country
# 0          17850.0  United Kingdom
# 1          17850.0  United Kingdom
# 2          17850.0  United Kingdom
# 3          17850.0  United Kingdom
# 4          17850.0  United Kingdom
# ...            ...             ...
# 541904     12680.0          France
# 541905     12680.0          France
# 541906     12680.0          France
# 541907     12680.0          France
# 541908     12680.0          France
#
# [541909 rows x 2 columns]

# %% [markdown]
# #### filter the dataframe where the index is 6

# %%
raw_data.filter(like='6', axis=0)
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 6         536365     21730   GLASS STAR FROSTED T-LIGHT HOLDER         6
# 16        536367     22622      BOX OF VINTAGE ALPHABET BLOCKS         2
# 26        536370     22728           ALARM CLOCK BAKELIKE PINK        24
# 36        536370     22659             LUNCH BOX I LOVE LONDON        24
# 46        536371     22086     PAPER CHAIN KIT 50'S CHRISTMAS         80
# ...          ...       ...                                 ...       ...
# 541869    581585     22481      BLACK TEA TOWEL CLASSIC DESIGN        12
# 541876    581585     84945  MULTI COLOUR SILVER T-LIGHT HOLDER        24
# 541886    581585     22398          MAGNETS PACK OF 4 SWALLOWS        12
# 541896    581587     22555           PLASTERS IN TIN STRONGMAN        12
# 541906    581587     23254       CHILDRENS CUTLERY DOLLY GIRL          4
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 6      2010-12-01 08:26:00       4.25     17850.0  United Kingdom
# 16     2010-12-01 08:34:00       9.95     13047.0  United Kingdom
# 26     2010-12-01 08:45:00       3.75     12583.0          France
# 36     2010-12-01 08:45:00       1.95     12583.0          France
# 46     2010-12-01 09:00:00       2.55     13748.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541869 2011-12-09 12:31:00       0.39     15804.0  United Kingdom
# 541876 2011-12-09 12:31:00       0.85     15804.0  United Kingdom
# 541886 2011-12-09 12:31:00       0.39     15804.0  United Kingdom
# 541896 2011-12-09 12:50:00       1.65     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
#
# [219035 rows x 8 columns]

# %% [markdown]
# #### Filter where the index begins with 5 or 8 using regex.

# %%
raw_data.filter(regex='5|8', axis=0)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 5         536365     22752     SET 7 BABUSHKA NESTING BOXES         2
# 8         536366     22632        HAND WARMER RED POLKA DOT         6
# 15        536367     22623    BOX OF VINTAGE JIGSAW BLOCKS          3
# 18        536367     21755         LOVE BUILDING BLOCK WORD         3
# 25        536369     21756         BATH BUILDING BLOCK WORD         3
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 5      2010-12-01 08:26:00       7.65     17850.0  United Kingdom
# 8      2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 15     2010-12-01 08:34:00       4.95     13047.0  United Kingdom
# 18     2010-12-01 08:34:00       5.95     13047.0  United Kingdom
# 25     2010-12-01 08:35:00       5.95     13047.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [378069 rows x 8 columns]
